# %% [markdown]
# <h1>ACTIVITY2: UK Accident Data</h1>
# <hr>
# <h2>Analyst: Anne Fedelino</h2>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
accident = pd.read_csv('datasets\\accident_data.csv')

# %%
accident
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious    05/06/2019  51.506187
# 1       200701BS65737           Serious    02/07/2019  51.495029
# 2       200701BS66127           Serious    26/08/2019  51.517715
# 3       200701BS66128           Serious    16/08/2019  51.495478
# 4       200701BS66837            Slight    03/09/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18/02/2022  57.374005
# 660675  201091NM01881            Slight    21/02/2022  57.232273
# 660676  201091NM01935            Slight    23/02/2022  57.585044
# 660677  201091NM01964           Serious    23/02/2022  57.214898
# 660678  201091NM02142           Serious    28/02/2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# 1                          Daylight  Kensington and Chelsea  -0.173647
# 2       Darkness - lighting unknown  Kensington and Chelsea  -0.210215
# 3                          Daylight  Kensington and Chelsea  -0.202731
# 4             Darkness - lights lit  Kensington and Chelsea  -0.192487
# ...                             ...                     ...        ...
# 660674                     Daylight                Highland  -3.467828
# 660675       Darkness - no lighting                Highland  -3.809281
# 660676                     Daylight                Highland  -3.862727
# 660677       Darkness - no lighting                Highland  -3.823997
# 660678                     Daylight                Highland  -3.895673
#
#         Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                          1                   2                     Dry
# 1                          1                   2             Wet or damp
# 2                          1                   3                     Dry
# 3                          1                   4                     Dry
# 4                          1                   2                     Dry
# ...                      ...                 ...                     ...
# 660674                     2                   1                     Dry
# 660675                     1                   1            Frost or ice
# 660676                     1                   3            Frost or ice
# 660677                     1                   2             Wet or damp
# 660678                     1                   1             Wet or damp
#
#                  Road_Type Urban_or_Rural_Area     Weather_Conditions  \
# 0       Single carriageway               Urban     Fine no high winds
# 1       Single carriageway               Urban  Raining no high winds
# 2                      NaN               Urban                    NaN
# 3       Single carriageway               Urban     Fine no high winds
# 4                      NaN               Urban                    NaN
# ...                    ...                 ...                    ...
# 660674  Single carriageway               Rural     Fine no high winds
# 660675  Single carriageway               Rural     Fine no high winds
# 660676  Single carriageway               Rural     Fine no high winds
# 660677  Single carriageway               Rural     Fine no high winds
# 660678    Dual carriageway               Rural  Snowing no high winds
#
#                                 Vehicle_Type
# 0                                        Car
# 1                                        Car
# 2                      Taxi/Private hire car
# 3       Bus or coach (17 or more pass seats)
# 4                              Other vehicle
# ...                                      ...
# 660674                                   Car
# 660675                                   Car
# 660676                                   Car
# 660677                 Motorcycle over 500cc
# 660678                                   Car
#
# [660679 rows x 14 columns]

# %%
accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660654 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660653 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                656159 non-null  object
#  11  Urban_or_Rural_Area      660664 non-null  object
#  12  Weather_Conditions       646551 non-null  object
#  13  Vehicle_Type             660679 non-null  object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 70.6+ MB

# %%
accident.describe()
# Out:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles
# count  660654.000000  660653.000000         660679.000000       660679.000000
# mean       52.553866      -1.431210              1.357040            1.831255
# std         1.406922       1.383330              0.824847            0.715269
# min        49.914430      -7.516225              1.000000            1.000000
# 25%        51.490690      -2.332291              1.000000            1.000000
# 50%        52.315641      -1.411667              1.000000            2.000000
# 75%        53.453452      -0.232869              1.000000            2.000000
# max        60.757544       1.762010             68.000000           32.000000

# %%
accident.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %% [markdown]
# <h2>Filling Null Values & Filling Missing Values</h2>

# %%
accident['Latitude'] = accident['Latitude'].fillna(accident['Latitude'].mean)
accident['Longitude'] = accident['Longitude'].fillna(accident['Longitude'].mean)
accident['Road_Surface_Conditions'] = accident['Road_Surface_Conditions'].fillna(accident['Road_Surface_Conditions'].mean)
accident['Road_Type'] = accident['Road_Type'].fillna(accident['Road_Type'].mean)
accident['Urban_or_Rural_Area'] = accident['Urban_or_Rural_Area'].fillna(accident['Urban_or_Rural_Area'].mean)
accident['Weather_Conditions'] = accident['Weather_Conditions'].fillna(accident['Weather_Conditions'].mean)

# %%
accident.isnull().sum()
# Out:
# Index                      0
# Accident_Severity          0
# Accident Date              0
# Latitude                   0
# Light_Conditions           0
# District Area              0
# Longitude                  0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# dtype: int64

# %%
accident.dtypes
# Out:
# Index                      object
# Accident_Severity          object
# Accident Date              object
# Latitude                   object
# Light_Conditions           object
# District Area              object
# Longitude                  object
# Number_of_Casualties        int64
# Number_of_Vehicles          int64
# Road_Surface_Conditions    object
# Road_Type                  object
# Urban_or_Rural_Area        object
# Weather_Conditions         object
# Vehicle_Type               object
# dtype: object

# %% [markdown]
# <h2>Adjusting Data Types</h2>

# %%
accident['Accident Date'] = pd.to_datetime(accident['Accident Date'], dayfirst = True, errors = 'coerce')

# %%
accident.dtypes
# Out:
# Index                              object
# Accident_Severity                  object
# Accident Date              datetime64[ns]
# Latitude                           object
# Light_Conditions                   object
# District Area                      object
# Longitude                          object
# Number_of_Casualties                int64
# Number_of_Vehicles                  int64
# Road_Surface_Conditions            object
# Road_Type                          object
# Urban_or_Rural_Area                object
# Weather_Conditions                 object
# Vehicle_Type                       object
# dtype: object

# %% [markdown]
# <h2>Extracting Date Information using Pandas Date Time</h3>

# %%
accident['Year'] = accident['Accident Date'].dt.year
accident['Month'] = accident['Accident Date'].dt.month
accident['Day'] = accident['Accident Date'].dt.day
accident['DayOfWeek'] = accident['Accident Date'].dt.dayofweek #moday=0, sunday=6

# %%
accident[['Year', 'Month', 'Day', 'DayOfWeek']].head()
# Out:
#    Year  Month  Day  DayOfWeek
# 0  2019      6    5          2
# 1  2019      7    2          1
# 2  2019      8   26          0
# 3  2019      8   16          4
# 4  2019      9    3          1

# %% [markdown]
# <h1>Data Analytics</h1>
# <h3>UniVariate</h3>
# <h3>Summary of Accidents in 2019</h3>
# <h3>Light Conditions</h3>
# <hr>

# %% [markdown]
# <h2>Univariate Analysis on Accident that happened in 2019</h2>

# %%
df_2019 = accident[accident['Year'] == 2019]

# %%
print(f"total number of accident in 2019 is {df_2019['Light_Conditions'].value_counts().sum()}")
df_2019['Light_Conditions'].value_counts()
# Out:
# total number of accident in 2019 is 182115
# Light_Conditions
# Daylight                       133042
# Darkness - lights lit           35769
# Darkness - no lighting          10842
# Darkness - lighting unknown      1768
# Darkness - lights unlit           694
# Name: count, dtype: int64

# %% [markdown]
# <h1>Data Analysis</h1>
# <hr>

# %% [markdown]
# <h1>Q1. What is the total number of casualties for each accident severity?</h1>

# %%
accident.groupby("Accident_Severity")["Number_of_Casualties"].sum()
# Out:
# Accident_Severity
# Fatal       16483
# Serious    129439
# Slight     750646
# Name: Number_of_Casualties, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>It shows that there were 16,483 fatal accidents, 12,9439 serious accidents, and 750,646 minor accidents.</h3>

# %% [markdown]
# <h3>INSIGHT 2:</h3>
# <h3>This shows that slight accidents have the highest number of casualties.</h3>

# %% [markdown]
# <h1>Q2. What is the maximum number of casualties in each accident severity category?</h1>

# %%
accident.groupby("Accident_Severity")["Number_of_Casualties"].max()
# Out:
# Accident_Severity
# Fatal      68
# Serious    45
# Slight     47
# Name: Number_of_Casualties, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>This shows that there were 68 fatal, 45 serious condition, and 47 in slight condition.</h3>

# %% [markdown]
# <h3>INSIGHT 2:</h3>
# <h3>Fatal accidents show the maximum casualties per accident.</h3>

# %% [markdown]
# <h1>Q3. What are the types of vehicles involved in accidents?</h1>

# %%
accident['Vehicle_Type'].value_counts()
# Out:
# Vehicle_Type
# Car                                      497992
# Van / Goods 3.5 tonnes mgw or under       34160
# Bus or coach (17 or more pass seats)      25878
# Motorcycle over 500cc                     25657
# Goods 7.5 tonnes mgw and over             17307
# Motorcycle 125cc and under                15269
# Taxi/Private hire car                     13294
# Motorcycle over 125cc and up to 500cc      7656
# Motorcycle 50cc and under                  7603
# Goods over 3.5t. and under 7.5t            6096
# Other vehicle                              5637
# Minibus (8 - 16 passenger seats)           1976
# Agricultural vehicle                       1947
# Pedal cycle                                 197
# Data missing or out of range                  6
# Ridden horse                                  4
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>The result above shows the vehicles involved in accidents.</h3>

# %% [markdown]
# <h3>INSIGHT 2:</h3>
# <h3>The car is the vehicle that has the most record involved in accidents.</h3>

# %% [markdown]
# <h1>Q4. How many accidents happened in each Urban_or_Rural_Area?</</h1>

# %%
accident["Urban_or_Rural_Area"].value_counts()
# Out:
# Urban_or_Rural_Area
# Urban                                                                                                                                                                                                                                                                                421663
# Rural                                                                                                                                                                                                                                                                                238990
# <bound method Series.mean of 0         Urban\n1         Urban\n2         Urban\n3         Urban\n4         Urban\n          ...  \n660674    Rural\n660675    Rural\n660676    Rural\n660677    Rural\n660678    Rural\nName: Urban_or_Rural_Area, Length: 660679, dtype: object>        15
# Unallocated                                                                                                                                                                                                                                                                              11
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>It shows that there were 421,678 vehicle accidents in urban areas, there are 238,990 vehicle accident in rural areas, and there are 11 accidents in unlocated areas.</h3>

# %% [markdown]
# <h3>INSIGHT 2:</h3>
# <h3>Districts with high population density record more vehicles involved in accidents.</h3>

# %% [markdown]
# <h3>INSIGHT 3:</h3>
# <h3>Urban areas often record more accidents than Rural areas.</h3>

# %% [markdown]
# <h1>Q5. What is the total number of casualties in urban vs rural areas?</h1>

# %%
accident.groupby("Urban_or_Rural_Area")["Number_of_Casualties"].sum()
# Out:
# Urban_or_Rural_Area
# <bound method Series.mean of 0         Urban\n1         Urban\n2         Urban\n3         Urban\n4         Urban\n          ...  \n660674    Rural\n660675    Rural\n660676    Rural\n660677    Rural\n660678    Rural\nName: Urban_or_Rural_Area, Length: 660679, dtype: object>        16
# Rural                                                                                                                                                                                                                                                                                353515
# Unallocated                                                                                                                                                                                                                                                                              13
# Urban                                                                                                                                                                                                                                                                                543024
# Name: Number_of_Casualties, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>The total number of casualties in rural areas is 353,515, in unlocated areas is 13, and there are 543,040 casualties in urban areas.</h3>

# %% [markdown]
# <h3>INSIGHT 2:</h3>
# <h3>This shows that urban areas report more accidents than rural area.</h3>

# %% [markdown]
# <h1>Q6. How many accidents happened in each Road_Type?</h1>

# %%
accident["Road_Type"].value_counts()
# Out:
# Road_Type
# Single carriageway                                                                                                                                                                                                                                                                                                                                                                                                        492143
# Dual carriageway                                                                                                                                                                                                                                                                                                                                                                                                           99424
# Roundabout                                                                                                                                                                                                                                                                                                                                                                                                                 43992
# One way street                                                                                                                                                                                                                                                                                                                                                                                                             13559
# Slip road                                                                                                                                                                                                                                                                                                                                                                                                                   7041
# <bound method Series.mean of 0         Single carriageway\n1         Single carriageway\n2                        NaN\n3         Single carriageway\n4                        NaN\n                 ...        \n660674    Single carriageway\n660675    Single carriageway\n660676    Single carriageway\n660677    Single carriageway\n660678      Dual carriageway\nName: Road_Type, Length: 660679, dtype: object>      4520
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>There are 496663 accidents on 'Single Carriageways', 99424 accidents on 'Dual Carriageways', 43992 accidents on 'Roundabouts', 13559 accidents on 'One-way streets', and 7041 accidents on 'Slip roads'.</h3>

# %% [markdown]
# <h3>INSIGHT 2:</h3>
# <h3>This shows that 'Single Carriageways dominate accidents by road types.</h3>

# %% [markdown]
# <h1>Q7. Which weather condition is most common in accidents?</h1>

# %%
accident["Weather_Conditions"].value_counts()
# Out:
# Weather_Conditions
# Fine no high winds                                                                                                                                                                                                                                                                                                                                                                                                                                                  520885
# Raining no high winds                                                                                                                                                                                                                                                                                                                                                                                                                                                79696
# Other                                                                                                                                                                                                                                                                                                                                                                                                                                                                17150
# <bound method Series.mean of 0            Fine no high winds\n1         Raining no high winds\n2                           NaN\n3            Fine no high winds\n4                           NaN\n                  ...          \n660674       Fine no high winds\n660675       Fine no high winds\n660676       Fine no high winds\n660677       Fine no high winds\n660678    Snowing no high winds\nName: Weather_Conditions, Length: 660679, dtype: object>     14128
# Raining + high winds                                                                                                                                                                                                                                                                                                                                                                                                                                                  9615
# Fine + high winds                                                                                                                                                                                                                                                                                                                                                                                                                                                     8554
# Snowing no high winds                                                                                                                                                                                                                                                                                                                                                                                                                                                 6238
# Fog or mist                                                                                                                                                                                                                                                                                                                                                                                                                                                           3528
# Snowing + high winds                                                                                                                                                                                                                                                                                                                                                                                                                                                   885
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHT:</h3>
# <h3>The result above shows that 'Fine no high winds' is the most common condition in accidents.</h3>

# %% [markdown]
# <h1>Q8. How manny serious accident are there in urban and rural area?</h1>

# %%
accident[accident["Accident_Severity"] == "Serious"]["Urban_or_Rural_Area"].value_counts()
# Out:
# Urban_or_Rural_Area
# Urban                                                                                                                                                                                                                                                                                50902
# Rural                                                                                                                                                                                                                                                                                37312
# <bound method Series.mean of 0         Urban\n1         Urban\n2         Urban\n3         Urban\n4         Urban\n          ...  \n660674    Rural\n660675    Rural\n660676    Rural\n660677    Rural\n660678    Rural\nName: Urban_or_Rural_Area, Length: 660679, dtype: object>        2
# Unallocated                                                                                                                                                                                                                                                                              1
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>Thsere are 50,904 seious condition in urban areas, in rural areas there are 37,312 serious accident, and only 1 serious accident happened in an unllocated area.</h3>

# %% [markdown]
# <h3>INSIGHT 2:</h3>
# <h3>This shows that Urban areas has more serious accident than rural(and unllocated area).</h3>

# %% [markdown]
# <h1>Q9. How many accidents of each severity happened under each light condition?</h1>

# %%
accident.groupby("Light_Conditions")["Accident_Severity"].value_counts()
# Out:
# Light_Conditions             Accident_Severity
# Darkness - lighting unknown  Slight                 5622
#                              Serious                 794
#                              Fatal                    68
# Darkness - lights lit        Slight               108345
#                              Serious               19130
#                              Fatal                  1860
# Darkness - lights unlit      Slight                 2138
#                              Serious                 360
#                              Fatal                    45
# Darkness - no lighting       Slight                28651
#                              Serious                7174
#                              Fatal                  1612
# Daylight                     Slight               419045
#                              Serious               60759
#                              Fatal                  5076
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>Daylight condition have the highest number of accidents across all severity.</h3>

# %% [markdown]
# <h1>Q10. What is the maximum number of casualties in urban_or_rural areas?</h1>

# %%
accident.groupby('Urban_or_Rural_Area')['Number_of_Casualties'].max()
# Out:
# Urban_or_Rural_Area
# <bound method Series.mean of 0         Urban\n1         Urban\n2         Urban\n3         Urban\n4         Urban\n          ...  \n660674    Rural\n660675    Rural\n660676    Rural\n660677    Rural\n660678    Rural\nName: Urban_or_Rural_Area, Length: 660679, dtype: object>     2
# Rural                                                                                                                                                                                                                                                                                68
# Unallocated                                                                                                                                                                                                                                                                           3
# Urban                                                                                                                                                                                                                                                                                32
# Name: Number_of_Casualties, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>The maximum number of casualties in Rural is 68, in Unllocated area is 3, and in Urban is 32.</h3>

# %% [markdown]
# <h3>INSIGHT 2:</h3>
# <h3>This shows that Rural has the highest maximum number of casualties in all of the area.</h3>

# %% [markdown]
# <h1>Q11. How many fatal accidents are there in Sheffield?</h1>

# %%
accident[(accident["Accident_Severity"] == "Fatal") & (accident["District Area"] == "Sheffield")]["District Area"].value_counts()
# Out:
# District Area
# Sheffield    38
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHT:</h3>
# <h3>There are 38 number of fatal accident that happened in Sheffield.</h3>

# %% [markdown]
# <h1>Q12. Which vehicle type is most often involved in accidents?</h1>

# %%
accident["Vehicle_Type"].value_counts()
# Out:
# Vehicle_Type
# Car                                      497992
# Van / Goods 3.5 tonnes mgw or under       34160
# Bus or coach (17 or more pass seats)      25878
# Motorcycle over 500cc                     25657
# Goods 7.5 tonnes mgw and over             17307
# Motorcycle 125cc and under                15269
# Taxi/Private hire car                     13294
# Motorcycle over 125cc and up to 500cc      7656
# Motorcycle 50cc and under                  7603
# Goods over 3.5t. and under 7.5t            6096
# Other vehicle                              5637
# Minibus (8 - 16 passenger seats)           1976
# Agricultural vehicle                       1947
# Pedal cycle                                 197
# Data missing or out of range                  6
# Ridden horse                                  4
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>According to the result, car is the most often involved in accidents.</h3>

# %% [markdown]
# <h3>INSIGHT 2:</h3>
# <h3>THere are 16 vehicles in the list that are involved in accident, but car has the most number of involved in accident.</h3>

# %% [markdown]
# <h1>Q13. What is the maximum and minimum number of vehicles involved by severity?</h1>

# %%
accident.groupby('Accident_Severity')['Number_of_Vehicles'].max()
# Out:
# Accident_Severity
# Fatal      28
# Serious    19
# Slight     32
# Name: Number_of_Vehicles, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>There are 28 vehicles involved in fatal, 19 vehicles involved in serious, snd there are 32 vehicles that are involved in slight condition.</h3>

# %% [markdown]
# <h3>INSIGHT 2:</h3>
# <h3>There are 32(maximum number) vehicles that are involved in slight severity.</h3>

# %% [markdown]
# <h3>INSIGHT 3:</h3>
# <h3>There are 19(minimum number) vehicles that are involved in serious severity.</h3>

# %% [markdown]
# <h1>Q14. Which light condition has the most fatal accidents?</h1>

# %%
accident[accident["Accident_Severity"] == "Fatal"]["Light_Conditions"].value_counts()
# Out:
# Light_Conditions
# Daylight                       5076
# Darkness - lights lit          1860
# Darkness - no lighting         1612
# Darkness - lighting unknown      68
# Darkness - lights unlit          45
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>Daylight has the highest/ most fatal accidents among the Accident Severity.</h3>

# %% [markdown]
# <h1>Q15. What is the minimum and maximum number of casualties recorded in an accident?</h1>

# %%
accident['Number_of_Casualties'].max()
# Out:
# np.int64(68)

# %%
accident['Number_of_Casualties'].min()
# Out:
# np.int64(1)

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>The maximum number of casualties is 68.</h3>

# %% [markdown]
# <h3>INSIGHT 2:</h3>
# <h3>The minimum number of casualties is 1.</h3>

# %% [markdown]
# <h1>Q16. How many accidents happened in urban and rural areas by road surface condition?</h1>

# %%
accident.groupby("Urban_or_Rural_Area")["Road_Surface_Conditions"].value_counts()
# Out:
# Urban_or_Rural_Area                                                                                                                                                                                                                                                                Road_Surface_Conditions
# <bound method Series.mean of 0         Urban\n1         Urban\n2         Urban\n3         Urban\n4         Urban\n          ...  \n660674    Rural\n660675    Rural\n660676    Rural\n660677    Rural\n660678    Rural\nName: Urban_or_Rural_Area, Length: 660679, dtype: object>  Dry                                                                                                                                                                                                                                                                                                                                                                       11
#                                                                                                                                                                                                                                                                                    Wet or damp                                                                                                                                                                                                                                                                                                                                                                2
#                                                                                                                                                                                                                                                                                    Frost or ice                                                                                                                                                                                                                                                                                                                                                               1
#                                                                                                                                                                                                                                                                                    Snow                                                                                                                                                                                                                                                                                                                                                                       1
# Rural                                                                                                                                                                                                                                                                              Dry                                                                                                                                                                                                                                                                                                                                                                   144861
#                                                                                                                                                                                                                                                                                    Wet or damp                                                                                                                                                                                                                                                                                                                                                            79005
#                                                                                                                                                                                                                                                                                    Frost or ice                                                                                                                                                                                                                                                                                                                                                           10953
#                                                                                                                                                                                                                                                                                    Snow                                                                                                                                                                                                                                                                                                                                                                    3102
#                                                                                                                                                                                                                                                                                    Flood over 3cm. deep                                                                                                                                                                                                                                                                                                                                                     785
#                                                                                                                                                                                                                                                                                    <bound method Series.mean of 0                  Dry\n1          Wet or damp\n2                  Dry\n3                  Dry\n4                  Dry\n              ...     \n660674             Dry\n660675    Frost or ice\n660676    Frost or ice\n660677     Wet or damp\n660678     Wet or damp\nName: Road_Surface_Conditions, Length: 660679, dtype: object>       284
# Unallocated                                                                                                                                                                                                                                                                        Dry                                                                                                                                                                                                                                                                                                                                                                        5
#                                                                                                                                                                                                                                                                                    Wet or damp                                                                                                                                                                                                                                                                                                                                                                5
#                                                                                                                                                                                                                                                                                    Flood over 3cm. deep                                                                                                                                                                                                                                                                                                                                                       1
# Urban                                                                                                                                                                                                                                                                              Dry                                                                                                                                                                                                                                                                                                                                                                   302944
#                                                                                                                                                                                                                                                                                    Wet or damp                                                                                                                                                                                                                                                                                                                                                           107696
#                                                                                                                                                                                                                                                                                    Frost or ice                                                                                                                                                                                                                                                                                                                                                            7563
#                                                                                                                                                                                                                                                                                    Snow                                                                                                                                                                                                                                                                                                                                                                    2787
#                                                                                                                                                                                                                                                                                    <bound method Series.mean of 0                  Dry\n1          Wet or damp\n2                  Dry\n3                  Dry\n4                  Dry\n              ...     \n660674             Dry\n660675    Frost or ice\n660676    Frost or ice\n660677     Wet or damp\n660678     Wet or damp\nName: Road_Surface_Conditions, Length: 660679, dtype: object>       442
#                                                                                                                                                                                                                                                                                    Flood over 3cm. deep                                                                                                                                                                                                                                                                                                                                                     231
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>In both urban and rural roads, most accidents happen on dry surfaces.</h3>

# %% [markdown]
# <h3>INSIGHT 2: </h3>
# <h3>However, wet and icy roads in rural areas appear riskier due to higher speeds and less road infrastructure.</h3>

# %% [markdown]
# <h1>Q17. Which weather condition records the highest number of accidents?</h1>

# %%
accident["Weather_Conditions"].value_counts()
# Out:
# Weather_Conditions
# Fine no high winds                                                                                                                                                                                                                                                                                                                                                                                                                                                  520885
# Raining no high winds                                                                                                                                                                                                                                                                                                                                                                                                                                                79696
# Other                                                                                                                                                                                                                                                                                                                                                                                                                                                                17150
# <bound method Series.mean of 0            Fine no high winds\n1         Raining no high winds\n2                           NaN\n3            Fine no high winds\n4                           NaN\n                  ...          \n660674       Fine no high winds\n660675       Fine no high winds\n660676       Fine no high winds\n660677       Fine no high winds\n660678    Snowing no high winds\nName: Weather_Conditions, Length: 660679, dtype: object>     14128
# Raining + high winds                                                                                                                                                                                                                                                                                                                                                                                                                                                  9615
# Fine + high winds                                                                                                                                                                                                                                                                                                                                                                                                                                                     8554
# Snowing no high winds                                                                                                                                                                                                                                                                                                                                                                                                                                                 6238
# Fog or mist                                                                                                                                                                                                                                                                                                                                                                                                                                                           3528
# Snowing + high winds                                                                                                                                                                                                                                                                                                                                                                                                                                                   885
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1: </h3>
# <h3>According to the result fine no high winds(clear) has the most  highest number of accidents.</h3>

# %% [markdown]
# <h3>INSIGHT 2:</h3>
# <h3>Rainig no high winds and fine no high winds are the two weather with hig number of accident, but no high wind is the highest with 535,013 accidents.</h3>

# %% [markdown]
# <h1>Q18. Which road type has the most accidents?</h1>

# %%
accident["Road_Type"].value_counts()
# Out:
# Road_Type
# Single carriageway                                                                                                                                                                                                                                                                                                                                                                                                        492143
# Dual carriageway                                                                                                                                                                                                                                                                                                                                                                                                           99424
# Roundabout                                                                                                                                                                                                                                                                                                                                                                                                                 43992
# One way street                                                                                                                                                                                                                                                                                                                                                                                                             13559
# Slip road                                                                                                                                                                                                                                                                                                                                                                                                                   7041
# <bound method Series.mean of 0         Single carriageway\n1         Single carriageway\n2                        NaN\n3         Single carriageway\n4                        NaN\n                 ...        \n660674    Single carriageway\n660675    Single carriageway\n660676    Single carriageway\n660677    Single carriageway\n660678      Dual carriageway\nName: Road_Type, Length: 660679, dtype: object>      4520
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHT: </h3>
# <h3>Single carriageway has the most accidents in record with 496663 number of accidents.</h3>

# %% [markdown]
# <h1>Q19. Which accident severity level is most common?</h1>

# %%
accident["Accident_Severity"].value_counts()
# Out:
# Accident_Severity
# Slight     563801
# Serious     88217
# Fatal        8661
# Name: count, dtype: int64

# %% [markdown]
# <h3>INSIGHT 1:</h3>
# <h3>Slight accidents is the most common accident severity level.</h3>

# %% [markdown]
# <h3>INSIGHT 2:</h3>
# <h3>Among those three severity level/accident severity, slight has the highest number with 563801, serious accident has 88217, and fatal has 8661.</h3>

# %% [markdown]
# <h2>Q20. How does accident severity vary under different light conditions?</h2>

# %%
accident_condition = accident.groupby("Light_Conditions")["Accident_Severity"].value_counts()

# %%
accident_condition
# Out:
# Light_Conditions             Accident_Severity
# Darkness - lighting unknown  Slight                 5622
#                              Serious                 794
#                              Fatal                    68
# Darkness - lights lit        Slight               108345
#                              Serious               19130
#                              Fatal                  1860
# Darkness - lights unlit      Slight                 2138
#                              Serious                 360
#                              Fatal                    45
# Darkness - no lighting       Slight                28651
#                              Serious                7174
#                              Fatal                  1612
# Daylight                     Slight               419045
#                              Serious               60759
#                              Fatal                  5076
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight 1:</h3>
# <h3>It shows that daylight light conditions have the highest number of accidents compared to other light conditions, and the severity that is highest is slight severity.</h3>

# %% [markdown]
# <h3>Insight 2:</h3>
# <h3>Many accidents also occur at night, even though the road is lit. The lights may be dim or the lights may be too far away, causing the accident.</h3>

# %% [markdown]
# <h1>Q21. Which District Area has the highest number of accident?</h1>

# %%
district_counts = accident['District Area'].value_counts().head(20)
district_counts

district_counts.plot(
    kind = 'barh',
    figsize = (18,10),
)
plt.title("Top 20 District with highest number of accident")
plt.xlabel("Number of Accidents")
plt.ylabel("District")
plt.show()

# %% [markdown]
# <h3>Insight 1:</h3>
# <h3>We can see in the graph above the top 20 district that has the most number of accident, these area might be busy or they are prone to accident. </h3>

# %% [markdown]
# <h3>Insight 2:</h3>
# <h3>Birmingham has the highest number of accidents in the top 20 districts with the most accidents.</h3>

# %% [markdown]
# <h2>Q22. What is the distribution of accident severities between Urban and Rural areas?</h2>

# %%
severity_area = (
    accident.groupby(['Urban_or_Rural_Area', 'Accident_Severity'])
            .size()
            .unstack(fill_value=0)
)

severity_area.plot(
    kind='bar',
    figsize=(14,8)
)

plt.title('Accident Severity Counts in Urban vs Rural Areas')
plt.xlabel('Area')
plt.ylabel('Number of Accidents')
plt.grid(axis='y', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Insight 1: </h3>
# <h3>This show that urban areas have higher counts across all severity levels.</h3>

# %% [markdown]
# <h3>Insight 2:</h3>
# <h3>Slight accidents are the most frequent in both urban and rural areas, which could mean that most crashes are minor collisions rather than high-impact incidents.</h3>

# %% [markdown]
# <h1>Q23.Which year had the most accidents in urban areas?</h1>

# %%
accident[accident['Urban_or_Rural_Area'] == 'Urban'] ['Accident Date'].dt.year.value_counts()
# Out:
# Accident Date
# 2019    114542
# 2020    108589
# 2021    104538
# 2022     93994
# Name: count, dtype: int64

# %% [markdown]
# <h3>Insight 1:</h3>
# <h3>This shows that one particular year(2019) has the highest number of accidents recordedd in urban. And the number of accidents in year 2022 decreases from 114542 to 93994.</h3>

# %% [markdown]
# <h1>Q24. Which month has the most accidents in rural areas?</h1>

# %%
rural_2020 = accident[(accident['Urban_or_Rural_Area'] == 'Rural') &  (accident['Accident Date'].dt.year == 2020)]

rural_monthly_2020 = rural_2020['Accident Date'].dt.month.value_counts().sort_index()

# Month labels
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

rural_monthly_2020.plot(
    kind='bar',
    figsize=(12,6),
    title='Monthly Rural Accidents in 2020'
)

plt.xlabel("Month")
plt.ylabel("Number of Accidents")
plt.xticks(ticks=range(12), labels=months, rotation=0)
plt.grid(axis='y', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Insight 1:</h3>
# <h3>MOnths like JUly and October have the highest number of rural accident in year 2020.</h3>

# %% [markdown]
# <h3>Insight 2:</h3>
# <h3>The month of april recorded the lowest number of accident, which might correspond to periods of reduced rural travel because of pandemic.</h3>

# %% [markdown]
# <h1>Q25. Which day of week sees the most fatal accidents?</h1>

# %%
fatal_acc = accident[accident['Accident_Severity'] == 'Fatal']

fatal_day_counts = fatal_acc['Accident Date'].dt.dayofweek.value_counts().sort_index()

fatal_day_counts.plot(
    kind='bar',
    figsize=(10,6),
    color='green',
    title='NUmber of fatal Accidents by Day of Week'
)

plt.xlabel("Day of Week")
plt.ylabel("Number of Fatal Accidents")
plt.xticks(
    ticks=range(7),
    labels=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'],
    rotation=0
)
plt.grid(axis='y', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Insight 1:</h3>
# <h3>Tuesday, Wednesday, Thursday, and Friday recorded a lower number of fatal accidents compared to other days, but they were still quite high.</h3>

# %% [markdown]
# <h3>Insight 2:</h3>
# <h3>The graph shows that the number fatal is higher on Monday, Saturday and Sunday. This could be because people are commuting to work (every Monday) and others are commuting home, or it could be because some people are out and about because they have no school (every Sunday).</h3>

# %% [markdown]
# <h1>Data Visualization</h1>

# %% [markdown]
# <h2>Q26. In which month do road accidents usually occur most frequently</h2>

# %%
monthly_data = accident.groupby(['Year','Month'])['Index'].count()
monthly_data = monthly_data.unstack(level=0)
monthly_data.plot(
    kind='bar',
    figsize=(12,8),
    title='Monthly Road Accidents by Year 2019 - 2022'
)
plt.xticks(
    range(0,12),
    ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sept','Oct','Nov','Dec'],
    rotation=0
)
plt.ylabel('Number of Accidents')
plt.xlabel('Month')
plt.grid(axis='y', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Insight 1:</h3>
# <h3>The graph shows that the year 2019 had the highest or most number of accidents compared to other year(2020-2022).</h3>

# %% [markdown]
# <h3>Insight 2:</h3>
# <h3>The graph above shows that the month of November had the highest number of accidents in the year 2019-2022. This may be the month when many people travel.</h3>

# %% [markdown]
# <h3>Insight 3:</h3>
# <h3>Month of February anf April seem to always have fewer accidents, showing that these months might be safer for travel.</h3>

# %% [markdown]
# <h2>Q26. How many accident happened in Oxford Area in year 2019-2022?</h2>

# %%
import matplotlib.pyplot as plt

oxford_acc = accident[accident['District Area'] == 'Oxford']
monthly_data = oxford_acc.groupby(['Year', 'Month'])['Index'].count()
monthly_data = monthly_data.unstack(level=0)

monthly_data.plot(
    marker='o', 
    figsize=(14, 8),
    title='Monthly Road Accidents in Oxford by Year (2019-2022)'
)
plt.xticks(
    range(1, 13),
    ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
)
plt.ylabel('Number of Accidents')
plt.xlabel('Month')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Insight 1:</h3>
# <h3>This show that year 2020 has the highest number of road accident in Oxford.</h3>

# %% [markdown]
# <h3>Insight 2:</h3>
# <h3>It can be seen here that in the year 2022, the number of road accidents decreased in the month of August, but it also increased in the month of November then decreased in the month of December.</h3>

# %% [markdown]
# <h2>Q27. Which month and year recorded the highest and lowest number of accidents in Canterbury?</h2>

# %%
canterbury_monthly = (canterbury_data.groupby([canterbury_data['Accident Date'].dt.year,canterbury_data['Accident Date'].dt.month])['Index'].count().unstack(level=0))

canterbury_monthly.plot(
    kind='bar',
    figsize=(12,6),
    title='Monthly Accidents in Canterbury (2020–2022)'
)

plt.xticks(
    ticks=range(0,12),
    labels=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
    rotation=0
)
plt.xlabel("Month")
plt.ylabel("Number of Accidents")
plt.grid(axis='y', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Insight 1:</h3>
# <h3>The year 2020 may show lower numbers in certain months due to pandemic restrictions, and the year 2021 shows a lower number of accidents per month, but it increased in the month of December, the year 2022 shows a low number of accidents (months January to October but the number of accidents increased in the month of November, and decreased in the month of December).</h3>

# %% [markdown]
# <h2>Q28. Which accident severity type is the most common in the dataset? </h2>

# %%
severity_counts = accident['Accident_Severity'].value_counts()
severity_counts

severity_counts.plot(
    kind='bar',
    figsize=(12,6),
    title='Accident Severity Counts in Urban vs Rural Areas'
)

plt.ylabel("Number of Accidents")
plt.xlabel("Accident Severity")
plt.show()

# %% [markdown]
# <h3>Insight 1:</h3>
# <h3>We can see that the highest number of accident per severity is the slight severity, may be caused by heavy traffic in busy areas, where vehicles move slowly but close together, increasing the chance of minor collisions. </h3>

# %% [markdown]
# <h2>Q29. In the district area of Blaby, which type of road records the highest number of accidents?</h2>

# %%
blaby_data = accident[accident['District Area'] == 'Blaby']

blaby_roads = blaby_data['Road_Type'].value_counts()

blaby_roads.plot(
    kind='bar',
    figsize=(10,6),
    color='skyblue',
    title='Road Types with Most Accidents in Blaby'
)

plt.xlabel("Road Type")
plt.ylabel("Number of Accidents")
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Insight 1:</h3>
# <h3>The graph shows that there are a large number of accidents on the single carriageway, followed by the dual carriageway with the highest number of accidents, and the road type with the fewest number is the one-way street.</h3>

# %% [markdown]
# <h2>Q30. What types of vehicle has the most number involved in accidents?</h2>

# %%
vehicle_counts = accident['Vehicle_Type'].value_counts().head(10)

vehicle_counts.plot(
    kind = 'barh',
    figsize = (12,8)
)
plt.title("Top 10 Vehicle Types in Accidents")
plt.xlabel("Number of Accidents")
plt.show()

# %% [markdown]
# <h3>Insight 1:</h3>
# <h3>It's obvious that car has the most number among top 10 that involved in accident. This also show that many people have cars and it's prone to accident.</h3>

# %% [markdown]
# <h3>Insight 2:</h3>
# <h3>These top 10 vehicle types are likely everyday transport vehicles because they’re more common on the road, like car, van, motorcycle and so on.</h3>

# %% [markdown]
# <h2>Q31. What is the distribution of accident severities in the district area of Darlington?</h2>

# %%
darlington_acc = accident[accident['District Area'] == 'Darlington']

severity_counts = darlington_acc['Accident_Severity'].value_counts()

severity_counts.plot(
    kind='bar',
    figsize=(8,6),
    color='skyblue',
    edgecolor='black'
)

plt.title("Accident Severity in Darlington")
plt.xlabel("Accident Severity")
plt.ylabel("Number of Accidents")
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Insight 1:</h3>
# <h3>Slight accidents are the most common in Darlington, the graph shows that the mojority of accident fall into slight severity category.</h3>

# %% [markdown]
# <h3>Insight 2:</h3>
# <h3>We see that serious severity is higher than fatal, it means responding immediately to emergencies and saving the lives of others.</h3>
